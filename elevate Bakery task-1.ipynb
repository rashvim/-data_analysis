# %%
import pandas as pd

# %%
data= pd.read_csv("Bakery Sales.csv")

# %%
data
# Out:
#               datetime day of week    total place  angbutter  plain bread  \
# 0     2019-07-11 15:35        Thur  23800.0   NaN        1.0          NaN
# 1     2019-07-11 16:10        Thur  15800.0   NaN        1.0          NaN
# 2     2019-07-12 11:49         Fri  58000.0   NaN        NaN          NaN
# 3     2019-07-13 13:19         Sat  14800.0   NaN        1.0          1.0
# 4     2019-07-13 13:22         Sat  15600.0   NaN        2.0          NaN
# ...                ...         ...      ...   ...        ...          ...
# 2649               NaN         NaN      NaN   NaN        NaN          NaN
# 2650               NaN         NaN      NaN   NaN        NaN          NaN
# 2651               NaN         NaN      NaN   NaN        NaN          NaN
# 2652               NaN         NaN      NaN   NaN        NaN          NaN
# 2653  2020-06-18 14:52         NaN      NaN   NaN        NaN          NaN
#
#       jam  americano  croissant  caffe latte  ...  gateau chocolat  pandoro  \
# ...

# %%
missing_value= data.isnull().sum()
missing_value
# Out:
# datetime               233
# day of week            234
# total                  234
# place                  488
# angbutter              681
# plain bread           1797
# jam                   2434
# americano             2242
# croissant             1907
# caffe latte           2461
# tiramisu croissant    1875
# cacao deep            2331
# pain au chocolat      2067
# almond croissant      2452
# croque monsieur       2654
# mad garlic            2654
# milk tea              2517
# gateau chocolat       2458
# pandoro               2311
# cheese cake           2564
# lemon ade             2619
# orange pound          2135
# wiener                2299
# vanila latte          2445
# berry ade             2600
# tiramisu              2647
# merinque cookies      2607
# dtype: int64

# %%
data.describe(include='object')
# Out:
#                 datetime day of week place
# count               2421        2420  2166
# unique              2361           7    19
# top     2019-11-09 11:36         Sun    동면
# freq                   9         554   416

# %%
data.describe()
# Out:
#               total    angbutter  plain bread         jam   americano  \
# count  2.420000e+03  1973.000000   857.000000  220.000000  412.000000
# mean   2.117252e+04     1.636594     1.199533    1.131818    1.245146
# std    2.699727e+04     1.115636     0.510268    0.433617    0.527216
# min    1.280000e+04     1.000000     1.000000    1.000000    1.000000
# 25%    1.580000e+04     1.000000     1.000000    1.000000    1.000000
# 50%    1.850000e+04     1.000000     1.000000    1.000000    1.000000
# 75%    2.300000e+04     2.000000     1.000000    1.000000    1.000000
# max    1.293000e+06    11.000000     5.000000    5.000000    5.000000
#
#         croissant  caffe latte  tiramisu croissant  cacao deep  \
# count  747.000000   193.000000          779.000000  323.000000
# mean     1.404284     1.108808            1.213094    1.126935
# std      1.027704     0.373016            0.797350    0.393249
# min      1.000000     1.000000            1.000000    1.000000
# ...

# %%
data.duplicated().sum()
# Out:
# 232

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#               datetime day of week    total  place  angbutter  plain bread  \
# 0     2019-07-11 15:35        Thur  23800.0    NaN        1.0          NaN
# 1     2019-07-11 16:10        Thur  15800.0    NaN        1.0          NaN
# 2     2019-07-12 11:49         Fri  58000.0    NaN        NaN          NaN
# 3     2019-07-13 13:19         Sat  14800.0    NaN        1.0          1.0
# 4     2019-07-13 13:22         Sat  15600.0    NaN        2.0          NaN
# ...                ...         ...      ...    ...        ...          ...
# 2417  2020-05-02 12:15         Sat  14300.0  효자 2동        1.0          1.0
# 2418  2020-05-02 13:45         Sat  15000.0    소양동        NaN          NaN
# 2419  2020-05-02 14:45         Sat  24100.0  효자 1동        2.0          NaN
# 2420               NaN         NaN      NaN    NaN        NaN          NaN
# 2653  2020-06-18 14:52         NaN      NaN    NaN        NaN          NaN
#
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data ['day of week'].value_counts()
# Out:
# day of week
# Sun     554
# Sat     452
# Thur    385
# Wed     360
# Fri     334
# Mon     332
# Tues      3
# Name: count, dtype: int64

# %%
data ['day of week'].unique()
# Out:
# array(['Thur', 'Fri', 'Sat', 'Sun', 'Mon', 'Wed', 'Tues', nan],
#       dtype=object)

# %%
data.dropna(subset=['day of week'],inplace=True)

# %%
import numpy as np
unique = 'Thur', 'Fri', 'Sat', 'Sun', 'Mon', 'Wed', 'Tues'
data['day of week'].apply(lambda x:x if x in unique else np.nan)
data['day of week'].unique()
data.dropna(subset=['day of week'],inplace=True)
data['day of week'].isnull().sum()
# Out:
# 0

# %%
data.total.isnull().sum()
# Out:
# 0

# %%
data.datetime.isnull().sum()
# Out:
# 0
